# %%
system("git clone https://github.com/QuocHieu59/VAEN")

# %%
dir.create("/kaggle/working/VAEN/DATA", recursive = TRUE, showWarnings = FALSE)  # Tạo folder đích nếu chưa có

# Sao chép toàn bộ nội dung folder
file.copy(from = list.files("/kaggle/input/data-ysinh/DATA", full.names = TRUE),
          to = "/kaggle/working/VAEN/DATA",
          recursive = TRUE)
# Out:
#  [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE

# %%
file.copy(from = list.files("/kaggle/input/data-sesult/data", full.names = TRUE),
          to = "/kaggle/working/VAEN/result/",
          recursive = TRUE)

file.copy(from = list.files("/kaggle/input/result-zn-ccle/result_ZN_CCLE", full.names = TRUE),
          to = "/kaggle/working/VAEN/result.EN/dr.CCLE/01",
          recursive = TRUE)
# Out:
#  [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [16] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [31] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [46] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
#  [1] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [16] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# [31] TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE
# logical(0)

# %%
file.copy(from = list.files("/kaggle/input/dr-gdsc-a-modelsrdata", full.names = TRUE),
          to = "/kaggle/working/VAEN/result.EN/dr.GDSC",
          recursive = TRUE)
# Out:
# [1] TRUE

# %%
install.packages("modEvA", dependencies = TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
source("/kaggle/working/VAEN/Figure/Figure2/Figure2A.R")

# %%
source("/kaggle/working/VAEN/Figure/Figure2/Figure2BCDE.R")
# Out:
# Loading required package: Matrix
#
# Loaded glmnet 4.1-8
# [1] "17-AAG" "503"    "879"
# [1] "AZD0530" "504"     "435"
# [1] "Erlotinib" "503"       "392"
# [1] "Lapatinib" "504"       "421"
# [1] "Nilotinib" "420"       "833"
# [1] "Nutlin-3" "504"      "878"
# [1] "Paclitaxel" "503"        "426"
# [1] "PD-0325901" "504"        "870"
# [1] "PD-0332991" "434"        "854"
# [1] "PF2341066" "504"       "433"
# [1] "PHA-665752" "503"        "434"
# [1] "PLX4720" "496"     "1824"
# [1] "Sorafenib" "503"       "430"
# [1] "TAE684" "504"    "433"
